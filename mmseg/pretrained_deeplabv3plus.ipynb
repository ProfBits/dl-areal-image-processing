# %% [markdown]
# # DeepLab V3 Plus

# %%
from mmseg.apis import inference_model, init_model, show_result_pyplot
import mmcv
import cv2
import matplotlib.pyplot as plt

# %%
img_raw = 'demopics/32686_5337.tif'
img_masked = 'demopics/32686_5337_masked.tif'  # or img = mmcv.imread(img), which will only load it once

img_raw = cv2.imread(img_raw)
img_raw = cv2.cvtColor(img_raw, cv2.COLOR_BGR2RGB)
# img_raw = cv2.resize(img_raw, (512,512))

img_masked = cv2.imread(img_masked)
img_masked = cv2.cvtColor(img_masked, cv2.COLOR_BGR2RGB)
# img_masked = cv2.resize(img_masked, (512,512))

# plt.imshow(img_raw)
# plt.imshow(img_masked)

# %%
img_raw_crop = img_raw[0:512, 0:512]
img_masked_crop = img_masked[0:512, 0:512]

# plt.imshow(img_raw_crop)
# plt.imshow(img_masked_crop)

# %% [markdown]
# ## LoveDA

# %%
loveDa_r18_config = r"mmsegmentation\configs\deeplabv3plus\deeplabv3plus_r18-d8_4xb4-80k_loveda-512x512.py"
loveDa_r18_checkpoint = r"checkpoints\DLV3P\deeplabv3plus_r18-d8_512x512_80k_loveda_20211104_132800-ce0fa0ca.pth"

loveDa_r18_model = init_model(loveDa_r18_config, loveDa_r18_checkpoint)
# Out:
# c:\Users\henha\miniconda3\envs\openmmlab\lib\site-packages\mmseg\models\builder.py:36: UserWarning: ``build_loss`` would be deprecated soon, please use ``mmseg.registry.MODELS.build()``
#   warnings.warn('``build_loss`` would be deprecated soon, please use '
# c:\Users\henha\miniconda3\envs\openmmlab\lib\site-packages\mmseg\models\losses\cross_entropy_loss.py:249: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   warnings.warn(
# Loads checkpoint by local backend from path: checkpoints\DLV3P\deeplabv3plus_r18-d8_512x512_80k_loveda_20211104_132800-ce0fa0ca.pth

# %%
# test a single image and show the results
loveDa_r18_im_raw = inference_model(loveDa_r18_model, img_raw)
# visualize the results in a new window
loveDa_r18_raw_result = show_result_pyplot(loveDa_r18_model, img_raw, loveDa_r18_im_raw, show=True, draw_pred=True, withLabels=False)
plt.imshow(loveDa_r18_raw_result)
# Out:
# c:\Users\henha\miniconda3\envs\openmmlab\lib\site-packages\mmengine\visualization\visualizer.py:196: UserWarning: Failed to add <class 'mmengine.visualization.vis_backend.LocalVisBackend'>, please provide the `save_dir` argument.
#   warnings.warn(f'Failed to add {vis_backend.__class__}, '

# %%
# test a single image and show the results
loveDa_r18_im_raw_crop = inference_model(loveDa_r18_model, img_raw_crop)
# visualize the results in a new window
loveDa_r18_raw_crop_result = show_result_pyplot(loveDa_r18_model, img_raw_crop, loveDa_r18_im_raw_crop, show=True, draw_pred=True, withLabels=False)
plt.imshow(loveDa_r18_raw_crop_result)

# %% [markdown]
# ## Vaihingen

# %%
vai_r18_config = r"mmsegmentation\configs\deeplabv3plus\deeplabv3plus_r18-d8_4xb4-80k_vaihingen-512x512.py"
vai_r18_checkpoint = r"checkpoints\DLV3P\deeplabv3plus_r18-d8_4x4_512x512_80k_vaihingen_20211231_230805-7626a263.pth"

vai_r18_model = init_model(vai_r18_config, vai_r18_checkpoint)
# Out:
# c:\Users\henha\miniconda3\envs\openmmlab\lib\site-packages\mmseg\models\builder.py:36: UserWarning: ``build_loss`` would be deprecated soon, please use ``mmseg.registry.MODELS.build()``
#   warnings.warn('``build_loss`` would be deprecated soon, please use '
# c:\Users\henha\miniconda3\envs\openmmlab\lib\site-packages\mmseg\models\losses\cross_entropy_loss.py:249: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   warnings.warn(
# Loads checkpoint by local backend from path: checkpoints\DLV3P\deeplabv3plus_r18-d8_4x4_512x512_80k_vaihingen_20211231_230805-7626a263.pth

# %%
# test a single image and show the results
vai_r18_im_raw = inference_model(vai_r18_model, img_raw)
# visualize the results in a new window
vai_r18_raw_result = show_result_pyplot(vai_r18_model, img_raw, vai_r18_im_raw, show=True, draw_pred=True, withLabels=False)
plt.imshow(vai_r18_raw_result)
# Out:
# c:\Users\henha\miniconda3\envs\openmmlab\lib\site-packages\mmengine\visualization\visualizer.py:196: UserWarning: Failed to add <class 'mmengine.visualization.vis_backend.LocalVisBackend'>, please provide the `save_dir` argument.
#   warnings.warn(f'Failed to add {vis_backend.__class__}, '

# %%
# test a single image and show the results
vai_r18_im_raw_crop = inference_model(vai_r18_model, img_raw_crop)
# visualize the results in a new window
vai_r18_raw_crop_result = show_result_pyplot(vai_r18_model, img_raw_crop, vai_r18_im_raw_crop, show=True, draw_pred=True, withLabels=False)
plt.imshow(vai_r18_raw_crop_result)

# %% [markdown]
# ## iSAID

# %%
iSAID_r18_config = r"mmsegmentation\configs\deeplabv3plus\deeplabv3plus_r18-d8_4xb4-80k_isaid-896x896.py"
iSAID_r18_checkpoint = r"checkpoints\DLV3P\deeplabv3plus_r18-d8_4x4_896x896_80k_isaid_20220110_180526-7059991d.pth"

iSAID_r18_model = init_model(iSAID_r18_config, iSAID_r18_checkpoint)
# Out:
# Loads checkpoint by local backend from path: checkpoints\DLV3P\deeplabv3plus_r18-d8_4x4_896x896_80k_isaid_20220110_180526-7059991d.pth

# %%
# test a single image and show the results
iSAID_r18_im_raw = inference_model(iSAID_r18_model, img_raw)
# visualize the results in a new window
iSAID_r18_raw_result = show_result_pyplot(iSAID_r18_model, img_raw, iSAID_r18_im_raw, show=True, draw_pred=True)
plt.imshow(iSAID_r18_raw_result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       2 iSAID_r18_im_raw = inference_model(iSAID_r18_model, img_raw)
#       3 # visualize the results in a new window
# ----> 4 iSAID_r18_raw_result = show_result_pyplot(iSAID_r18_model, img_raw, iSAID_r18_im_raw, show=True, draw_pred=True)
#       5 plt.imshow(iSAID_r18_raw_result)
#
# File c:\Users\henha\miniconda3\envs\openmmlab\lib\site-packages\mmseg\apis\inference.py:177, in show_result_pyplot(model, img, result, opacity, title, draw_gt, draw_pred, wait_time, show, withLabels, save_dir, out_file)
#     170 visualizer = SegLocalVisualizer(
#     171     vis_backends=[dict(type='LocalVisBackend')],
#     172     save_dir=save_dir,
#     173     alpha=opacity)
#     174 visualizer.dataset_meta = dict(
#     175     classes=model.dataset_meta['classes'],
#     176     palette=model.dataset_meta['palette'])
# ...
